# %%
from bs4 import BeautifulSoup # html을 soup에 넣고 특정 class or data를 가져오는 library
import re
from urllib.parse import urlencode
from urllib.request import Request, urlopen
import requests

# %%
url = "http://blog.naver.com/PostList.nhn?blogId=yonggeol93&currentPage=1"

# %%
r = requests.get(url)
bs = BeautifulSoup(r.text, 'lxml')
bs
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="ko">
# <head>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="noindex,nofollow" name="robots"/>
# <meta content="always" name="referrer"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!--[if ie]>
# <style type="text/css">
# html {overflow: scroll; overflow-x: auto;}
# </style>
# <![endif]-->
# <link charset="UTF-8" href="http://t.static.blog.naver.net/mylog/versioning/LayoutTopCommon-398889296.css" rel="stylesheet" type="text/css"/>
# <link href="http://t.static.blog.naver.net/mylog/versioning//common/css/music/player-d3fc09e.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon"/>
# <meta content="GreenD93's Daily : 네이버 블로그" property="og:title"/>
# ...

# %%
bs.find_all("iframe")
# Out:
# [<iframe allowtransparency="true" frameborder="0" height="1" id="RewFrm221293773658" scrolling="no" src="" style="display:none" title="엮인글" width="100%"></iframe>,
#  <iframe allowtransparency="true" frameborder="0" height="1" id="sympathyFrm221293773658" scrolling="no" src="" style="display:none" title="공감처리" width="100%"></iframe>,
#  <iframe height="0" id="saveTagNameFrame" name="saveTagNameFrame" src="" style="display:none" title="포스트별 태그정보 저장용 프레임" width="0"></iframe>,
#  <iframe frameborder="0" height="163" id="layeredframe" marginheight="0" marginwidth="0" scrolling="no" src="about:blank" title="레이어용 프레임" width="350"></iframe>,
#  <iframe frameborder="0" height="252" id="captchalayeredframe" marginheight="0" marginwidth="0" scrolling="no" src="about:blank" title="안부게시판 캡차" width="504"></iframe>,
# ...

# %%
blog_id = "yonggeol93"
page = 3
url = "http://blog.naver.com/PostList.nhn?blogId=" + blog_id + "&currentPage=" + str(page)
r = requests.get(url)
bs = BeautifulSoup(r.text, 'lxml')
print(url)
# Out:
# http://blog.naver.com/PostList.nhn?blogId=yonggeol93&currentPage=3

# %%
content = bs.find("div", {"id": "postViewArea"})
content
# Out:
# <div id="postViewArea">
# <div class="post-view pcol2 _param(1) _postViewArea221230536533" id="post-view221230536533">
# ...
