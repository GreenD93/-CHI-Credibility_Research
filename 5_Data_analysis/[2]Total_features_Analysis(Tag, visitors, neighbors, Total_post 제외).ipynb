# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('[Final]Total_csv.csv',sep='\t',encoding='utf-8')

# %%
df.columns.tolist()
# Out:
# ['Post_id',
#  'Title_len',
#  'Count_space_mistake',
#  'Map_exist',
#  'Media_count',
#  'Heart_count',
#  'Sticker_count',
#  'Comment_count',
#  'Left',
#  'Center',
#  'Right',
#  'Justify',
#  'basic_font_check',
#  'basic_font_size_check',
#  'b_strong_word_len_ratio',
#  'color_rgb_word_len_ratio',
#  'First_ratio',
#  'Second_ratio',
#  'Text_len',
#  'Img_count',
#  'FR_url',
#  'pos_ratio',
#  'neg_ratio',
#  'subjectivity',
#  'polarity',
#  'senti_diffs_per_ref',
#  '가능하다',
#  '가다',
#  '간단하다',
#  '갈다',
#  '계시다',
#  '궁금하다',
#  '그렇다',
#  '깔끔하다',
#  '나가다',
#  '나다',
#  '나오다',
#  '남다',
#  '내다',
#  '너무',
#  '넘다',
#  '넣다',
#  '높다',
#  '느끼다',
#  '늘다',
#  '다니다',
#  '다르다',
#  '다양하다',
#  '덥다',
#  '돼다',
#  '되다',
#  '되어다',
#  '두다',
#  '드리다',
#  '들다',
#  '들어가다',
#  '들이다',
#  '따르다',
#  '만나다',
#  '만들다',
#  '많다',
#  '많이',
#  '말다',
#  '맛있다',
#  '맞다',
#  '먹다',
#  '모르다',
#  '믿다',
#  '바라다',
#  '받다',
#  '버리다',
#  '보내다',
#  '보다',
#  '보이다',
#  '빠르다',
#  '빠지다',
#  '새롭다',
#  '생기다',
#  '서다',
#  '쉬다',
#  '시원하다',
#  '싶다',
#  '쓰다',
#  '아니다',
#  '아직',
#  '안녕하다',
#  '안되다',
#  '않다',
#  '알다',
#  '알아보다',
#  '어떻다',
#  '어렵다',
#  '없다',
#  '없이',
#  '예쁘다',
#  '오다',
#  '올리다',
#  '원하다',
#  '유명하다',
#  '이렇게',
#  '이렇다',
#  '이르다',
#  '인하다',
#  '자다',
#  '자세하다',
#  '작다',
#  '잡다',
#  '저렴하다',
#  '적다',
#  '좋다',
#  '좋아하다',
#  '주다',
#  '중요하다',
#  '즐기다',
#  '지다',
#  '찍다',
#  '차다',
#  '찾다',
#  '크다',
#  '특히',
#  '편하다',
#  '필요하다',
#  '해드리다',
#  '해보다',
#  '해주다',
#  '힘들다',
#  'img img img img img',
#  'img img img img text',
#  'img img img text img',
#  'img img text img img',
#  'img img text img text',
#  'img text img img img',
#  'img text img img text',
#  'img text img text img',
#  'text img img img img',
#  'text img img img text',
#  'text img img text img',
#  'text img text img img',
#  'text img text img text',
#  '24시스터디카페',
#  'it',
#  'lg액정수리',
#  '강남서울밝은안과',
#  '결혼',
#  '결혼준비',
#  '골프',
#  '공연',
#  '교육',
#  '국내여행',
#  '귀성형수술',
#  '김앤방여성의원',
#  '누운귀성형',
#  '눈썹문신',
#  '다이어트',
#  '대전맛집',
#  '더새로이',
#  '데일리룩',
#  '돌출귀성형',
#  '드라마',
#  '디자인',
#  '로맨틱그랑서울',
#  '리뷰',
#  '만화',
#  '맛집',
#  '몬스터폰',
#  '미용',
#  '뱃살성형',
#  '뱃살수술',
#  '복부성형',
#  '복부성형가격',
#  '복부성형후기',
#  '복부수술',
#  '본스타트레이닝센터',
#  '부산',
#  '부산치과',
#  '비에이블스터디카페',
#  '사진',
#  '생각',
#  '세계여행',
#  '스터디장소',
#  '스터디카페',
#  '스터디카페추천',
#  '스포츠',
#  '스포츠분석',
#  '스포츠중계',
#  '시험준비',
#  '신차드림',
#  '아나레슨',
#  '아나운서학원',
#  '아이폰배터리할인',
#  '아이폰수리',
#  '아이폰액정수리',
#  '애니',
#  '애니메이션',
#  '어린이영양제',
#  '에이치비성형외과',
#  '여행',
#  '연기학원',
#  '영어공부',
#  '영어회화',
#  '영화',
#  '웨딩박람회',
#  '육아',
#  '이벤트',
#  '일본여행',
#  '일상',
#  '임플란트',
#  '입꼬리성형',
#  '입꼬리성형수술',
#  '입꼬리수술',
#  '입꼬리수술비용',
#  '입꼬리수술잘하는곳',
#  '자격증',
#  '자동차',
#  '자동차리스',
#  '장기렌트',
#  '장기렌트카',
#  '재택알바',
#  '제주도',
#  '제주도여행',
#  '제주여행',
#  '주식',
#  '주식투자',
#  '줄기세포가슴지방이식',
#  '중간고사',
#  '중고폰매입',
#  '직장인미팅',
#  '직장인솔로대첩',
#  '창업',
#  '처진뱃살',
#  '첫글',
#  '청담여신성형외과',
#  '취미',
#  '키성장영양제',
#  '키영양제',
#  '키크는방법',
#  '키크는법',
#  '패션',
#  '학문',
#  'Question_count',
#  'Tag_count',
#  'Blog_info_text_len',
#  'Count_neighbors',
#  'Count_visitors',
#  'Post_interval_average',
#  'Text_similarity',
#  'Total_post',
#  'User_Id_len',
#  'User_Id_contain_num',
#  'User_Id_contain_char',
#  'Comment_interaction',
#  'Count_categories',
#  'Average_comment_diff',
#  'First_comment_diff',
#  'Opening_date',
#  'Blog_mobile_profile_img',
#  'Blog_mobile_cover_img',
#  'effort_ratio',
#  'effort_img_ratio',
#  'experience',
#  'Credibility']

# %%
df[['Left',
 'Center',
 'Right',
 'Justify',
'pos_ratio',
 'neg_ratio',
 'subjectivity',
 'polarity',
'Opening_date',
'Blog_mobile_profile_img',
'Blog_info_text_len',
'Comment_interaction',
 'effort_ratio',
 'effort_img_ratio',
'Count_categories',
 'Average_comment_diff',
 'First_comment_diff',
 'Text_similarity',
'Post_interval_average'
   ]]
# Out:
#         Left  Center  Right  Justify     pos_ratio     neg_ratio  \
# 0        0.0     7.0    0.0      0.0  3.474178e-02  5.915493e-02
# 1        0.0    66.0    0.0      0.0  3.296703e-02  6.593407e-02
# 2        3.0    41.0    0.0      0.0  7.547170e-02  5.660377e-02
# 3        0.0    90.0    0.0      0.0  2.302632e-02  3.947368e-02
# 4        0.0    55.0    0.0      0.0  5.494505e-02  4.395604e-02
# 5        0.0    72.0    0.0      0.0  5.649718e-02  5.084746e-02
# 6        2.0   106.0    0.0      0.0  3.296703e-02  5.494505e-02
# 7        0.0   156.0    0.0      0.0  3.376623e-02  6.233766e-02
# 16294                    0  5.619422e-02          0.000000                35
# 16295                    0  4.656092e-02          0.000000                35
# 16296                    0  4.415260e-02          0.000000                35
# 16297                    1  1.134784e+00          2.330265                21
# 16298                    0  3.745085e-01          0.768007                22
# 16299                    0  2.095241e-01          0.296200                75
# 16300                    0  8.212383e-01          1.283534                75
# 16301                    1  2.328046e-02          0.691134                75
# 16302                    1  3.845290e-01          0.098733                75
# 16303                    1  1.595113e+00          0.197467                75
#
#        Average_comment_diff  First_comment_diff  Text_similarity  \
# 0              1.769372e+07             27900.0         0.232631
# 1              1.306840e+06           1266060.0         0.112250
# 2              1.462390e+07            546900.0         0.071837
# 3              1.187202e+06           1150980.0         0.246814
# 4                       NaN                 NaN         0.227445
# 5              1.177949e+07           1879800.0         0.221925
# 6              2.218290e+06           2215920.0         0.043462
# 7              1.392540e+06           1355460.0         0.065938
# 8              1.220250e+05            162720.0         0.086118
# 9                       NaN                 NaN              NaN
# 10             2.919195e+06             39180.0         0.195875
# 11                      NaN                 NaN              NaN
# 12             8.121600e+05             78240.0              NaN
# 13             9.907500e+06           7640220.0         0.356026
# 14             8.152558e+07           1020780.0         0.114211
# 15             1.011467e+05             53520.0              NaN
# 16             1.459492e+05              3180.0              NaN
# 17             3.813231e+04             94140.0              NaN
# 18             3.299714e+04              2460.0         0.413853
# 19                      NaN                 NaN         0.407363
# 20                      NaN                 NaN         0.351408
# 21             1.158635e+08         115864500.0         0.299522
# 22                      NaN                 NaN         0.314266
# 23                      NaN                 NaN         0.296623
# 24                      NaN                 NaN         0.277720
# 25             2.725200e+04             99840.0         0.432451
# 26             2.444000e+04              1200.0         0.387590
# 27             1.573581e+06            205320.0              NaN
# 28             2.329532e+06             23280.0              NaN
# 29             6.397238e+06            549780.0              NaN
# ...                     ...                 ...              ...
# 16274                   NaN                 NaN         0.167855
# 16275                   NaN                 NaN         0.245641
# 16276                   NaN                 NaN         0.373772
# 16277                   NaN                 NaN         0.364360
# 16278                   NaN                 NaN         0.376117
# 16279          4.230118e+07          58707360.0         0.341863
# 16280                   NaN                 NaN         0.385524
# 16281          3.000000e+03              3000.0         0.213676
# 16282          1.082400e+05            108240.0         0.356955
# 16283          1.081500e+05            187920.0         0.347388
# 16284                   NaN                 NaN         0.400699
# 16285                   NaN                 NaN         0.362767
# 16286                   NaN                 NaN         0.293585
# 16287          3.039316e+07          43925460.0         0.307773
# 16288                   NaN                 NaN         0.206772
# 16289                   NaN                 NaN         0.238595
# 16290          2.133615e+07          38971140.0         0.184839
# 16291          5.112000e+05            502440.0         0.019745
# 16292                   NaN                 NaN              NaN
# 16293                   NaN                 NaN              NaN
# 16294                   NaN                 NaN              NaN
# 16295                   NaN                 NaN              NaN
# 16296                   NaN                 NaN              NaN
# 16297          7.455788e+07          84422700.0         0.251945
# 16298                   NaN                 NaN         0.200324
# 16299          2.976540e+06           2976540.0              NaN
# 16300                   NaN                 NaN         0.088539
# 16301          1.656092e+05           1836960.0              NaN
# 16302          1.750080e+05            283200.0         0.103403
# 16303          2.815400e+05            392100.0         0.047738
#
#        Post_interval_average
# 0                  10.666667
# 1                  10.666667
# 2                  10.666667
# 3                  10.666667
# 4                  10.666667
# 5                  10.666667
# 6                  10.666667
# 7                  10.666667
# 8                  10.666667
# 9                  10.666667
# 10                 59.333333
# 11                 59.333333
# 12                 59.333333
# 13                 59.333333
# 14                 59.333333
# 15                  1.500000
# 16                  1.500000
# 17                  1.500000
# 18                  1.500000
# 19                  0.500000
# 20                112.200000
# 21                  0.500000
# 22                  0.500000
# 23                  0.500000
# 24                  0.500000
# 25                  1.500000
# 26                  1.500000
# 27                 87.000000
# 28                 87.000000
# 29                 87.000000
# ...                      ...
# 16274              26.833333
# 16275              26.833333
# 16276               1.000000
# 16277               1.000000
# 16278               1.000000
# 16279              26.833333
# 16280               1.000000
# 16281               3.333333
# 16282               1.000000
# 16283               1.000000
# 16284               1.000000
# 16285               1.000000
# 16286               1.000000
# 16287              26.833333
# 16288              26.833333
# 16289              26.833333
# 16290              26.833333
# 16291               8.333333
# 16292              42.400000
# 16293              42.400000
# 16294              42.400000
# 16295              42.400000
# 16296              42.400000
# 16297              26.833333
# 16298               1.333333
# 16299              61.666667
# 16300              61.666667
# 16301              61.666667
# 16302              61.666667
# 16303              61.666667
#
# [16304 rows x 19 columns]

# %%
df[['img img img img img','img img img img text',
 'img img img text img',
 'img img text img img',
 'img img text img text',
 'img text img img img',
 'img text img img text',
 'img text img text img',
 'text img img img img',
 'text img img img text',
 'text img img text img',
 'text img text img img',
 'text img text img text']]
# Out:
#        img img img img img  img img img img text  img img img text img  \
# 0                 0.000000              0.000000              0.000000
# 1                 0.000000              0.000000              0.000000
# 2                 0.000000              0.000000              0.000000
# 3                 0.000000              0.000000              0.000000
# 4                 0.000000              0.000000              0.000000
# 5                 0.000000              0.000000              0.000000
# 6                 0.000000              0.000000              0.000000
# 7                 0.000000              0.000000              0.000000
# 8                 0.000000              0.000000              0.000000
# 9                 0.000000              0.000000              0.000000
# 10                0.000000              0.000000              0.000000
# 11                0.000000              0.000000              0.000000
# 12                0.000000              0.000000              0.000000
# 13                0.000000              0.000000              0.000000
# 14                0.000000              0.000000              0.000000
# 15                1.000000              0.000000              0.000000
# 16                1.000000              0.000000              0.000000
# 17                1.000000              0.000000              0.000000
# 18                0.000000              0.000000              0.000000
# 19                0.000000              0.000000              0.000000
# 20                0.000000              0.000000              0.000000
# 21                0.000000              0.000000              0.000000
# 22                0.000000              0.000000              0.000000
# 23                0.000000              0.000000              0.000000
# 24                0.000000              0.000000              0.000000
# 25                0.000000              0.000000              0.000000
# 26                0.000000              0.000000              0.000000
# 27                0.000000              0.000000              0.000000
# 28                0.000000              0.000000              0.000000
# 29                0.000000              0.000000              0.000000
# ...                    ...                   ...                   ...
# 16274             0.000000              0.000000              0.000000
# 16275             0.000000              0.000000              0.000000
# 16276             0.000000              0.000000              0.000000
# 16277             0.000000              0.000000              0.000000
# 16278             0.000000              0.000000              0.000000
# 16279             0.000000              0.000000              0.000000
# 16280                0.720132
# 16281                0.238544
# 16282                0.720607
# 16283                0.720132
# 16284                0.721674
# 16285                0.724423
# 16286                0.726237
# 16287                0.630492
# 16288                0.000000
# 16289                0.000000
# 16290                0.000000
# 16291                0.000000
# 16292                0.000000
# 16293                0.000000
# 16294                0.000000
# 16295                0.000000
# 16296                0.000000
# 16297                0.614653
# 16298                0.726237
# 16299                0.894575
# 16300                0.674645
# 16301                0.000000
# 16302                0.000000
# 16303                0.000000
#
# [16304 rows x 13 columns]

# %%
df.columns.tolist()
# Out:
# ['Post_id',
#  'Title_len',
#  'Count_space_mistake',
#  'Map_exist',
#  'Media_count',
#  'Heart_count',
#  'Sticker_count',
#  'Comment_count',
#  'Left',
#  'Center',
#  'Right',
#  'Justify',
#  'basic_font_check',
#  'basic_font_size_check',
#  'b_strong_word_len_ratio',
#  'color_rgb_word_len_ratio',
#  'First_ratio',
#  'Second_ratio',
#  'Text_len',
#  'Img_count',
#  'FR_url',
#  'pos_ratio',
#  'neg_ratio',
#  'subjectivity',
#  'polarity',
#  'senti_diffs_per_ref',
#  '가능하다',
#  '가다',
#  '간단하다',
#  '갈다',
#  '계시다',
#  '궁금하다',
#  '그렇다',
#  '깔끔하다',
#  '나가다',
#  '나다',
#  '나오다',
#  '남다',
#  '내다',
#  '너무',
#  '넘다',
#  '넣다',
#  '높다',
#  '느끼다',
#  '늘다',
#  '다니다',
#  '다르다',
#  '다양하다',
#  '덥다',
#  '돼다',
#  '되다',
#  '되어다',
#  '두다',
#  '드리다',
#  '들다',
#  '들어가다',
#  '들이다',
#  '따르다',
#  '만나다',
#  '만들다',
#  '많다',
#  '많이',
#  '말다',
#  '맛있다',
#  '맞다',
#  '먹다',
#  '모르다',
#  '믿다',
#  '바라다',
#  '받다',
#  '버리다',
#  '보내다',
#  '보다',
#  '보이다',
#  '빠르다',
#  '빠지다',
#  '새롭다',
#  '생기다',
#  '서다',
#  '쉬다',
#  '시원하다',
#  '싶다',
#  '쓰다',
#  '아니다',
#  '아직',
#  '안녕하다',
#  '안되다',
#  '않다',
#  '알다',
#  '알아보다',
#  '어떻다',
#  '어렵다',
#  '없다',
#  '없이',
#  '예쁘다',
#  '오다',
#  '올리다',
#  '원하다',
#  '유명하다',
#  '이렇게',
#  '이렇다',
#  '이르다',
#  '인하다',
#  '자다',
#  '자세하다',
#  '작다',
#  '잡다',
#  '저렴하다',
#  '적다',
#  '좋다',
#  '좋아하다',
#  '주다',
#  '중요하다',
#  '즐기다',
#  '지다',
#  '찍다',
#  '차다',
#  '찾다',
#  '크다',
#  '특히',
#  '편하다',
#  '필요하다',
#  '해드리다',
#  '해보다',
#  '해주다',
#  '힘들다',
#  'img img img img img',
#  'img img img img text',
#  'img img img text img',
#  'img img text img img',
#  'img img text img text',
#  'img text img img img',
#  'img text img img text',
#  'img text img text img',
#  'text img img img img',
#  'text img img img text',
#  'text img img text img',
#  'text img text img img',
#  'text img text img text',
#  '24시스터디카페',
#  'it',
#  'lg액정수리',
#  '강남서울밝은안과',
#  '결혼',
#  '결혼준비',
#  '골프',
#  '공연',
#  '교육',
#  '국내여행',
#  '귀성형수술',
#  '김앤방여성의원',
#  '누운귀성형',
#  '눈썹문신',
#  '다이어트',
#  '대전맛집',
#  '더새로이',
#  '데일리룩',
#  '돌출귀성형',
#  '드라마',
#  '디자인',
#  '로맨틱그랑서울',
#  '리뷰',
#  '만화',
#  '맛집',
#  '몬스터폰',
#  '미용',
#  '뱃살성형',
#  '뱃살수술',
#  '복부성형',
#  '복부성형가격',
#  '복부성형후기',
#  '복부수술',
#  '본스타트레이닝센터',
#  '부산',
#  '부산치과',
#  '비에이블스터디카페',
#  '사진',
#  '생각',
#  '세계여행',
#  '스터디장소',
#  '스터디카페',
#  '스터디카페추천',
#  '스포츠',
#  '스포츠분석',
#  '스포츠중계',
#  '시험준비',
#  '신차드림',
#  '아나레슨',
#  '아나운서학원',
#  '아이폰배터리할인',
#  '아이폰수리',
#  '아이폰액정수리',
#  '애니',
#  '애니메이션',
#  '어린이영양제',
#  '에이치비성형외과',
#  '여행',
#  '연기학원',
#  '영어공부',
#  '영어회화',
#  '영화',
#  '웨딩박람회',
#  '육아',
#  '이벤트',
#  '일본여행',
#  '일상',
#  '임플란트',
#  '입꼬리성형',
#  '입꼬리성형수술',
#  '입꼬리수술',
#  '입꼬리수술비용',
#  '입꼬리수술잘하는곳',
#  '자격증',
#  '자동차',
#  '자동차리스',
#  '장기렌트',
#  '장기렌트카',
#  '재택알바',
#  '제주도',
#  '제주도여행',
#  '제주여행',
#  '주식',
#  '주식투자',
#  '줄기세포가슴지방이식',
#  '중간고사',
#  '중고폰매입',
#  '직장인미팅',
#  '직장인솔로대첩',
#  '창업',
#  '처진뱃살',
#  '첫글',
#  '청담여신성형외과',
#  '취미',
#  '키성장영양제',
#  '키영양제',
#  '키크는방법',
#  '키크는법',
#  '패션',
#  '학문',
#  'Question_count',
#  'Tag_count',
#  'Blog_info_text_len',
#  'Count_neighbors',
#  'Count_visitors',
#  'Post_interval_average',
#  'Text_similarity',
#  'Total_post',
#  'User_Id_len',
#  'User_Id_contain_num',
#  'User_Id_contain_char',
#  'Comment_interaction',
#  'Count_categories',
#  'Average_comment_diff',
#  'First_comment_diff',
#  'Opening_date',
#  'Blog_mobile_profile_img',
#  'Blog_mobile_cover_img',
#  'effort_ratio',
#  'effort_img_ratio',
#  'experience',
#  'Credibility']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('[Final]Total_csv.csv',sep='\t',encoding='utf-8')

# %%
df_space = df[['Post_id','Count_space_mistake']]

# %%
df_space.to_csv('Count_mistake.csv',encoding='utf-8',sep='\t',index=False)

# %%
df[['Post_id','effort_img_ratio','effort_ratio', 'img img img img img',
 'img img img img text',
 'img img img text img',
 'img img text img img',
 'img img text img text',
 'img text img img img',
 'img text img img text',
 'img text img text img',
 'text img img img img',
 'text img img img text',
 'text img img text img',
 'text img text img img',
 'text img text img text',
  'Left',
 'Center',
 'Right',
 'Justify']].to_csv('additional_feature_from_user_study.csv',sep='\t',encoding='utf-8',index=False)

# %%
df[['polarity']].to_csv('polarity_socre.csv',encoding='utf-8',sep='\t',index= False)

# %%
drop_column_list = ['Post_id','Blog_info_text_len','Count_neighbors','Count_visitors', 'Post_interval_average',
 'Comment_count',
 'Heart_count',
 'Text_similarity',
 'Total_post',
 'User_Id_len',
 'User_Id_contain_num',
 'User_Id_contain_char',
 'Comment_interaction',
 'Count_categories',
 'Average_comment_diff',
 'First_comment_diff',
 'Opening_date',
 'Blog_mobile_profile_img',
 'Blog_mobile_cover_img',
 'experience',
'Text_len',
 'Img_count']

# %%
Tag = [ '가능하다',
 '가다',
 '간단하다',
 '갈다',
 '계시다',
 '궁금하다',
 '그렇다',
 '깔끔하다',
 '나가다',
 '나다',
 '나오다',
 '남다',
 '내다',
 '너무',
 '넘다',
 '넣다',
 '높다',
 '느끼다',
 '늘다',
 '다니다',
 '다르다',
 '다양하다',
 '덥다',
 '돼다',
 '되다',
 '되어다',
 '두다',
 '드리다',
 '들다',
 '들어가다',
 '들이다',
 '따르다',
 '만나다',
 '만들다',
 '많다',
 '많이',
 '말다',
 '맛있다',
 '맞다',
 '먹다',
 '모르다',
 '믿다',
 '바라다',
 '받다',
 '버리다',
 '보내다',
 '보다',
 '보이다',
 '빠르다',
 '빠지다',
 '새롭다',
 '생기다',
 '서다',
 '쉬다',
 '시원하다',
 '싶다',
 '쓰다',
 '아니다',
 '아직',
 '안녕하다',
 '안되다',
 '않다',
 '알다',
 '알아보다',
 '어떻다',
 '어렵다',
 '없다',
 '없이',
 '예쁘다',
 '오다',
 '올리다',
 '원하다',
 '유명하다',
 '이렇게',
 '이렇다',
 '이르다',
 '인하다',
 '자다',
 '자세하다',
 '작다',
 '잡다',
 '저렴하다',
 '적다',
 '좋다',
 '좋아하다',
 '주다',
 '중요하다',
 '즐기다',
 '지다',
 '찍다',
 '차다',
 '찾다',
 '크다',
 '특히',
 '편하다',
 '필요하다',
 '해드리다',
 '해보다',
 '해주다',
 '힘들다',
    '24시스터디카페',
 'it',
 'lg액정수리',
 '강남서울밝은안과',
 '결혼',
 '결혼준비',
 '골프',
 '공연',
 '교육',
 '국내여행',
 '귀성형수술',
 '김앤방여성의원',
 '누운귀성형',
 '눈썹문신',
 '다이어트',
 '대전맛집',
 '더새로이',
 '데일리룩',
 '돌출귀성형',
 '드라마',
 '디자인',
 '로맨틱그랑서울',
 '리뷰',
 '만화',
 '맛집',
 '몬스터폰',
 '미용',
 '뱃살성형',
 '뱃살수술',
 '복부성형',
 '복부성형가격',
 '복부성형후기',
 '복부수술',
 '본스타트레이닝센터',
 '부산',
 '부산치과',
 '비에이블스터디카페',
 '사진',
 '생각',
 '세계여행',
 '스터디장소',
 '스터디카페',
 '스터디카페추천',
 '스포츠',
 '스포츠분석',
 '스포츠중계',
 '시험준비',
 '신차드림',
 '아나레슨',
 '아나운서학원',
 '아이폰배터리할인',
 '아이폰수리',
 '아이폰액정수리',
 '애니',
 '애니메이션',
 '어린이영양제',
 '에이치비성형외과',
 '여행',
 '연기학원',
 '영어공부',
 '영어회화',
 '영화',
 '웨딩박람회',
 '육아',
 '이벤트',
 '일본여행',
 '일상',
 '임플란트',
 '입꼬리성형',
 '입꼬리성형수술',
 '입꼬리수술',
 '입꼬리수술비용',
 '입꼬리수술잘하는곳',
 '자격증',
 '자동차',
 '자동차리스',
 '장기렌트',
 '장기렌트카',
 '재택알바',
 '제주도',
 '제주도여행',
 '제주여행',
 '주식',
 '주식투자',
 '줄기세포가슴지방이식',
 '중간고사',
 '중고폰매입',
 '직장인미팅',
 '직장인솔로대첩',
 '창업',
 '처진뱃살',
 '첫글',
 '청담여신성형외과',
 '취미',
 '키성장영양제',
 '키영양제',
 '키크는방법',
 '키크는법',
 '패션',
 '학문']

# %%
drop_column_sum = drop_column_list + Tag

# %%
new_df = df.drop(drop_column_sum,axis=1)

# %%
new_df.columns.tolist()
# Out:
# ['Title_len',
#  'Count_space_mistake',
#  'Map_exist',
#  'Media_count',
#  'Sticker_count',
#  'Left',
#  'Center',
#  'Right',
#  'Justify',
#  'basic_font_check',
#  'basic_font_size_check',
#  'b_strong_word_len_ratio',
#  'color_rgb_word_len_ratio',
#  'First_ratio',
#  'Second_ratio',
#  'FR_url',
#  'pos_ratio',
#  'neg_ratio',
#  'subjectivity',
#  'polarity',
#  'senti_diffs_per_ref',
#  'img img img img img',
#  'img img img img text',
#  'img img img text img',
#  'img img text img img',
#  'img img text img text',
#  'img text img img img',
#  'img text img img text',
#  'img text img text img',
#  'text img img img img',
#  'text img img img text',
#  'text img img text img',
#  'text img text img img',
#  'text img text img text',
#  'Question_count',
#  'Tag_count',
#  'effort_ratio',
#  'effort_img_ratio',
#  'Credibility']

# %% [markdown]
# # Heart_count
# # Comment_count

# %%
# new_df['Heart_count'] = new_df['Heart_count'].apply(lambda x : 0 if x =='hide' else x)
# new_df['Comment_count'] = new_df['Comment_count'].apply(lambda x : 0 if x =='hide' else x)

# %%
Analysis_df = new_df.fillna(0)

# %%
# Analysis_df.to_csv('[Final]Analysis_df.csv',sep='\t',encoding='utf-8',index=False)

# %%
column_list = Analysis_df.columns.tolist()

# %%
# Analysis_df.groupby(by='Credibility')['Heart_count'].count()

# %% [markdown]
# ## Data 개수 맞춰주기

# %%
# naver_df = Analysis_df[Analysis_df['Credibility']==1]
# dbdbdeep_df = Analysis_df[Analysis_df['Credibility']==0]

# from sklearn.utils import shuffle
# naver_df = shuffle(naver_df)
# naver_df.shape

# naver_df = naver_df.iloc[:6362]

# dbdbdeep_df.shape

# Analysis_df = pd.concat([naver_df,dbdbdeep_df])

# %% [markdown]
# # Data shuffle

# %%
from sklearn.utils import shuffle
Analysis_df = shuffle(Analysis_df)

# %%
x = Analysis_df.drop(columns='Credibility',axis=1)
y = Analysis_df[['Credibility']]
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(x) 

# Min-max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(copy=True, feature_range=(0, 1))
scaler.fit(x) 
X_scaled = pd.DataFrame(scaler.transform(x),columns = x.columns)

# %% [markdown]
# ## Chi-squre feature selection

# %%
feature_name = X_scaled.columns.tolist()

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
chi2_selector = SelectKBest(chi2, k=20)
chi2_selector.fit(X_scaled, y)

# Look at scores returned from the selector for each feature
chi2_scores = pd.DataFrame(list(zip(feature_name, chi2_selector.scores_, chi2_selector.pvalues_)), columns=['ftr', 'score', 'pval'])
chi2_scores

# you can see that the kbest returned from SelectKBest 
#+ were the two features with the _highest_ score
kbest = np.asarray(feature_name)[chi2_selector.get_support()]

# %%
feature_dict = dict(zip(feature_name,chi2_selector.scores_))
ranking_list = reversed(sorted(feature_dict.items(), key =lambda feature_dict:feature_dict[1]))
print('Feature ranking:')
for feature in ranking_list:
    #print ('feature : %d %s (%f)' % (num+1,Feautre_list[feature[0]],feature[1]))
    print(feature[0])
# Out:
# Feature ranking:
# FR_url
# img text img text img
# text img text img text
# Map_exist
# img img img img img
# Sticker_count
# basic_font_size_check
# img img img text img
# text img img img img
# img img img img text
# img text img img img
# text img img img text
# img text img img text
# basic_font_check
# Tag_count
# polarity
# Center
# img img text img img
# Media_count
# neg_ratio
# text img text img img
# Right
# text img img text img
# subjectivity
# First_ratio
# Title_len
# Second_ratio
# effort_img_ratio
# Question_count
# Left
# img img text img text
# effort_ratio
# Justify
# b_strong_word_len_ratio
# color_rgb_word_len_ratio
# Count_space_mistake
# senti_diffs_per_ref
# pos_ratio

# %% [markdown]
# # Train model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_scaled , y , test_size=0.33, random_state=42)

# %%
x = Analysis_df.drop(columns='Credibility',axis=1)
y = Analysis_df[['Credibility']]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_scaled = pd.DataFrame(scaler.transform(x),columns = x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_scaled , y , test_size=0.33, random_state=42)

# %% [markdown]
# # Random Foreset

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(x_train, y_train)
# Out:
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
print("RF :",accuracy_score(clf.predict(x_test),y_test))
# Out:
# RF : 0.8355324289165582

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, clf.predict(x_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.80      0.78      0.79      2100
#           1       0.86      0.87      0.87      3281
#
# avg / total       0.84      0.84      0.84      5381

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(clf, X_scaled, y, cv=5)
scores
# Out:
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# array([0.83813611, 0.83476395, 0.84478528, 0.8208589 , 0.81625767])

# %%
importances = clf.feature_importances_
std = np.std([clf.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_scaled.shape[1]):
    #print("%d. feature: %s (%f)" % (f + 1, Feautre_list[indices[f]], importances[indices[f]]))
    print(feature_name[indices[f]])
    #print(importances[indices[f]])
# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(x_train.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(x_train.shape[1]), indices)
plt.xlim([-1, x_train.shape[1]])
plt.show()
# Out:
# Feature ranking:
# effort_img_ratio
# Center
# text img text img text
# FR_url
# Count_space_mistake
# img text img text img
# effort_ratio
# Title_len
# Sticker_count
# Justify
# b_strong_word_len_ratio
# img text img img text
# text img img img img
# First_ratio
# Tag_count
# Map_exist
# Media_count
# Left
# Question_count
# Right
# basic_font_check
# basic_font_size_check
# color_rgb_word_len_ratio
# Second_ratio
# text img img img text
# text img text img img
# pos_ratio
# neg_ratio
# text img img text img
# polarity
# senti_diffs_per_ref
# img img img img img
# img img img img text
# img img img text img
# img img text img img
# img img text img text
# img text img img img
# subjectivity

# %% [markdown]
# # Logistic Regression

# %%
from  sklearn  import  linear_model
logreg = linear_model.LogisticRegression(C=2.0,random_state=42,solver='sag',multi_class='multinomial',warm_start=True)
logreg.fit(x_train, y_train)
# Out:
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/linear_model/sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# LogisticRegression(C=2.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=42, solver='sag',
#           tol=0.0001, verbose=0, warm_start=True)

# %%
print("RF :",accuracy_score(logreg.predict(x_test),y_test))
# Out:
# RF : 0.8240104069875488

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, logreg.predict(x_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.78      0.77      0.77      2100
#           1       0.85      0.86      0.86      3281
#
# avg / total       0.82      0.82      0.82      5381

# %%
feature_importance = abs(logreg.coef_[0])
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

featfig = plt.figure()
featax = featfig.add_subplot(1, 1, 1)
featax.barh(pos, feature_importance[sorted_idx], align='center')
featax.set_yticks(pos)
featax.set_yticklabels(np.array(x_train.columns)[sorted_idx], fontsize=5)
featax.set_xlabel('Relative Feature Importance')

plt.tight_layout()   
plt.show()

# %%
feature_dict = dict(zip(feature_name,feature_importance))
ranking_list = reversed(sorted(feature_dict.items(), key =lambda feature_dict:feature_dict[1]))
print('Feature ranking:')
for feature in ranking_list:
    #print ('feature : %d %s (%f)' % (num+1,Feautre_list[feature[0]],feature[1]))
    print(feature[0])
# Out:
# Feature ranking:
# Count_space_mistake
# effort_ratio
# Left
# img text img text img
# effort_img_ratio
# FR_url
# img img img img img
# img img text img img
# text img text img text
# img text img img text
# First_ratio
# Sticker_count
# text img img img img
# basic_font_size_check
# text img img text img
# img text img img img
# img img text img text
# img img img img text
# neg_ratio
# Map_exist
# basic_font_check
# Media_count
# senti_diffs_per_ref
# Right
# subjectivity
# img img img text img
# Title_len
# b_strong_word_len_ratio
# Question_count
# text img img img text
# polarity
# color_rgb_word_len_ratio
# text img text img img
# Second_ratio
# Tag_count
# Justify
# pos_ratio
# Center

# %% [markdown]
# ## MLP

# %%
import time
from sklearn.neural_network import MLPClassifier

# %%
mlp_clf = MLPClassifier(
    hidden_layer_sizes=(50,),
    max_iter=35,
    alpha=1e-4,
    solver='sgd',
    verbose=10,
    tol=1e-4,
    random_state=1,
    learning_rate_init=.1
)

# %%
start = time.time()
mlp_clf.fit(x_train, y_train)
end = time.time()
print('Time: {:f}s'.format(end-start))
# Out:
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:912: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.46607942
# Iteration 2, loss = 0.37152806
# Iteration 3, loss = 0.33812261
# Iteration 4, loss = 0.31551200
# Iteration 5, loss = 0.30301187
# Iteration 6, loss = 0.29865208
# Iteration 7, loss = 0.28736178
# Iteration 8, loss = 0.27347309
# Iteration 9, loss = 0.27195587
# Iteration 10, loss = 0.26837688
# Iteration 11, loss = 0.26127453
# Iteration 12, loss = 0.26079747
# Iteration 13, loss = 0.25691411
# Iteration 14, loss = 0.25405190
# Iteration 15, loss = 0.24612885
# Iteration 16, loss = 0.24547541
# Iteration 17, loss = 0.24153067
# Iteration 18, loss = 0.23840232
# Iteration 19, loss = 0.23694671
# Iteration 20, loss = 0.23674680
# Iteration 21, loss = 0.24039127
# Iteration 22, loss = 0.23330531
# Iteration 23, loss = 0.23445525
# Iteration 24, loss = 0.22798582
# Iteration 25, loss = 0.22729440
# Iteration 26, loss = 0.22770467
# Iteration 27, loss = 0.21767278
# Iteration 28, loss = 0.22469917
# Iteration 29, loss = 0.21990601
# Iteration 30, loss = 0.22163868
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Time: 0.895044s

# %%
y_pred = mlp_clf.predict(x_test)
print("테스트 정확도: {:.3f}".format(accuracy_score(y_pred, y_test)))
# Out:
# 테스트 정확도: 0.881

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, mlp_clf.predict(x_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.88      0.85      2113
#           1       0.92      0.88      0.90      3268
#
# avg / total       0.88      0.88      0.88      5381

# %% [markdown]
# # OLS Regression Results

# %%
import statsmodels.api as sm
x_2 = sm.add_constant(x)
est = sm.OLS(y,x_2.astype(float)).fit()

# %%
print(est.summary())
