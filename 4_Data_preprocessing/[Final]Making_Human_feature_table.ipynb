# %%
import os
import sqlite3
import pandas as pd
import tqdm

# %%
db_name = '[TFIDF]Credibility_research_20180905.db' #DB 파일명
# db 생성
con = sqlite3.connect( db_name )
cur = con.cursor()

# %%
def refined_category(category):
    refined_list = []
    for i in category.split('], '):
        try:
            category_count = int(i.split(', ')[0].replace('[','').replace("'",''))
            categoty_title = i.split(', ')[1]
            categoty_title = i.split(', ')[1].replace(']]','')
            categoty_title = categoty_title.replace(')]','')
            refined_list.append((category_count,categoty_title))
        except:
            pass
    return refined_list

# %%
Human_centered_df = pd.read_csv('For_Human_feature.csv',sep='\t',encoding='utf-8')

# %%
Human_centered_df
# Out:
#             Post_id  Title_len  Count_space_mistake  Map_exist  Media_count  \
# 0      100027815366         24                100.0        0.0          0.0
# 1      100050521880         41                  8.0        0.0          1.0
# 2      100052476065         37                 10.0        0.0          0.0
# 3      100052627538         34                 28.0        0.0          0.0
# 4      100052919717         24                 11.0        0.0          0.0
# 5      100053144381         48                 11.0        0.0          0.0
# 6      100053820465         34                 24.0        0.0          0.0
# 7      100054338281         36                 38.0        0.0          4.0
# 8      100064414352         13                 14.0        0.0          0.0
# 9      100067528683         21                  0.0        0.0          0.0
# 10      10007492085         21                  9.0        0.0          0.0
# ...

# %%
def refined_category(category):
    refined_list = []
    for i in category.split('"),'):
        try:
            category_count = int(i.split(', ')[0].replace('[','').replace("'",''))
            categoty_title = i.split(', ')[1]
            categoty_title = i.split(', ')[1].replace(']]','')
            categoty_title = categoty_title.replace(')]','')
            refined_list.append((category_count,categoty_title))
        except:
            pass
    return refined_list

# %%
### Human_centered_df['Category_list'].iloc[4].split('"),')[0].split(',')

# %%
text = Human_centered_df['Category_list'].iloc[0].split('),')[1].split(',')[0]

# %%
int(re.findall('\d+', text)[0])
# Out:
# 17

# %%
Category = Human_centered_df['Category_list'].tolist()

# %%
Category_average_count = []
for i in Category:
    Category_list = i.split('),')
    temp_list = []
    for j in Category_list:
        Number = j.split(',')[0]
        try:
            Count = int(re.findall('\d+', Number)[0])
        except:
            if "수필" in Number:
                Count = 73
        if Count != 0:
            temp_list.append(Count)
    temp_sum = sum(temp_list)
    temp_count = len(temp_list)
    Category_average_count.append(temp_sum/temp_count)

# %%
Human_centered_df['experience'] = Category_average_count

# %% [markdown]
# # 정성 여부

# %%
Category_len = Human_centered_df.groupby(by='Category')['Text_len'].mean().to_dict()

# %%
Img_len = Human_centered_df.groupby(by='Category')['Img_count'].mean().to_dict()

# %%
Img_len
# Out:
# {'IT·컴퓨터': 10.128282828282828,
#  '건강·의학': 8.582714382174206,
#  '공연·전시': 12.55934065934066,
#  '교육·학문': 10.158496732026144,
#  '국내여행': 26.041441441441442,
#  '드라마·방송': 11.486739469578783,
#  '등산·낚시·레저': 23.269372693726936,
#  '만화·애니': 17.366032210834554,
#  '맛집': 18.8370720188902,
#  '사진': 13.06946876824285,
#  '스포츠': 8.87403314917127,
#  '시사·인문·경제': 5.872727272727273,
#  '어학·외국어': 11.586510263929618,
#  '와인·술': 7.527027027027027,
#  '육아·결혼': 15.317307692307692,
#  '자동차': 17.298047276464544,
#  '차·커피·디저트': 14.595382746051033,
#  '패션·뷰티': 14.654545454545454}

# %%
Human_df = Human_centered_df[['Post_id','Category','Text_len','Img_count']]

# %%
Ca = Human_df['Category'].tolist()
Tex = Human_df['Text_len'].tolist()
Img_cnt =  Human_df['Img_count'].tolist()

# %%
effort_text = []
effort_img = []

for i in range(0,len(Ca)):
    effort_text.append(Tex[i]/Category_len[Ca[i]])
    effort_img.append(Img_cnt[i]/Img_len[Ca[i]])

# %%
Human_df['effort_text'] = effort_text
Human_df['effort_img'] = effort_img
# Out:
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/yonggeol/miniconda3/envs/py/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Human_df.to_csv('Human_update_features.csv',sep='\t',encoding='utf-8',index=False)

# %%
Total_computational_df['Category_list'] = Category_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-9033f9c4d82e> in <module>()
# ----> 1 Total_computational_df['Category_list'] = Category_df
#
# NameError: name 'Category_df' is not defined

# %%
Total_computational_df.to_csv('For_Human_feature.csv',encoding='utf-8',sep='\t',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a4267a7483e1> in <module>()
# ----> 1 Total_computational_df.to_csv('For_Human_feature.csv',encoding='utf-8',sep='\t',index=False)
#
# NameError: name 'Total_computational_df' is not defined

# %% [markdown]
# # Feautre_총합

# %%
Feature = feature_1 + feature_2

# %%
Human_centered_df[Feature].to_csv('[Final]Human_df.csv',encoding='utf-8',sep='\t',index=False)

# %%
Feature
# Out:
# ['effort_text',
#  'effort_img',
#  'experience',
#  'Img_count',
#  'Media_count',
#  'Map_exist',
#  'Left',
#  'Center',
#  'Right',
#  'Justify',
#  'basic_font_check',
#  'basic_font_size_check',
#  'b_strong_word_len_ratio',
#  'color_rgb_word_len_ratio',
#  'FR_url',
#  'Sticker_count',
#  'Blog_info_text_len',
#  'Opening_date',
#  'Title_len',
#  'Text_similarity',
#  'pos_ratio',
#  'neg_ratio',
#  'polarity',
#  'Comment_count',
#  'Heart_count',
#  'Post_interval_average',
#  'Total_post',
#  'Credibility',
#  'img img img img img',
#  'img img img img text',
#  'img img img text img',
#  'img img text img img',
#  'img img text img text',
#  'img text img img img',
#  'img text img img text',
#  'img text img text img',
#  'text img img img img',
#  'text img img img text',
#  'text img img text img',
#  'text img text img img',
#  'text img text img text',
#  '24시스터디카페',
#  'it',
#  'lg액정수리',
#  '강남서울밝은안과',
#  '결혼',
#  '결혼준비',
#  '골프',
#  '공연',
#  '교육',
#  '국내여행',
# ...

# %%
feature_2 = ['img img img img img',
 'img img img img text',
 'img img img text img',
 'img img text img img',
 'img img text img text',
 'img text img img img',
 'img text img img text',
 'img text img text img',
 'text img img img img',
 'text img img img text',
 'text img img text img',
 'text img text img img',
 'text img text img text',
'24시스터디카페',
 'it',
 'lg액정수리',
 '강남서울밝은안과',
 '결혼',
 '결혼준비',
 '골프',
 '공연',
 '교육',
 '국내여행',
 '귀성형수술',
 '김앤방여성의원',
 '누운귀성형',
 '눈썹문신',
 '다이어트',
 '대전맛집',
 '더새로이',
 '데일리룩',
 '돌출귀성형',
 '드라마',
 '디자인',
 '로맨틱그랑서울',
 '리뷰',
 '만화',
 '맛집',
 '몬스터폰',
 '미용',
 '뱃살성형',
 '뱃살수술',
 '복부성형',
 '복부성형가격',
 '복부성형후기',
 '복부수술',
 '본스타트레이닝센터',
 '부산',
 '부산치과',
 '비에이블스터디카페',
 '사진',
 '생각',
 '세계여행',
 '스터디장소',
 '스터디카페',
 '스터디카페추천',
 '스포츠',
 '스포츠분석',
 '스포츠중계',
 '시험준비',
 '신차드림',
 '아나레슨',
 '아나운서학원',
 '아이폰배터리할인',
 '아이폰수리',
 '아이폰액정수리',
 '애니',
 '애니메이션',
 '어린이영양제',
 '에이치비성형외과',
 '여행',
 '연기학원',
 '영어공부',
 '영어회화',
 '영화',
 '웨딩박람회',
 '육아',
 '이벤트',
 '일본여행',
 '일상',
 '임플란트',
 '입꼬리성형',
 '입꼬리성형수술',
 '입꼬리수술',
 '입꼬리수술비용',
 '입꼬리수술잘하는곳',
 '자격증',
 '자동차',
 '자동차리스',
 '장기렌트',
 '장기렌트카',
 '재택알바',
 '제주도',
 '제주도여행',
 '제주여행',
 '주식',
 '주식투자',
 '줄기세포가슴지방이식',
 '중간고사',
 '중고폰매입',
 '직장인미팅',
 '직장인솔로대첩',
 '창업',
 '처진뱃살',
 '첫글',
 '청담여신성형외과',
 '취미',
 '키성장영양제',
 '키영양제',
 '키크는방법',
 '키크는법',
 '패션',
 '학문',
'가능하다',
 '가다',
 '간단하다',
 '갈다',
 '계시다',
 '궁금하다',
 '그렇다',
 '깔끔하다',
 '나가다',
 '나다',
 '나오다',
 '남다',
 '내다',
 '너무',
 '넘다',
 '넣다',
 '높다',
 '느끼다',
 '늘다',
 '다니다',
 '다르다',
 '다양하다',
 '덥다',
 '돼다',
 '되다',
 '되어다',
 '두다',
 '드리다',
 '들다',
 '들어가다',
 '들이다',
 '따르다',
 '만나다',
 '만들다',
 '많다',
 '많이',
 '말다',
 '맛있다',
 '맞다',
 '먹다',
 '모르다',
 '믿다',
 '바라다',
 '받다',
 '버리다',
 '보내다',
 '보다',
 '보이다',
 '빠르다',
 '빠지다',
 '새롭다',
 '생기다',
 '서다',
 '쉬다',
 '시원하다',
 '싶다',
 '쓰다',
 '아니다',
 '아직',
 '안녕하다',
 '안되다',
 '않다',
 '알다',
 '알아보다',
 '어떻다',
 '어렵다',
 '없다',
 '없이',
 '예쁘다',
 '오다',
 '올리다',
 '원하다',
 '유명하다',
 '이렇게',
 '이렇다',
 '이르다',
 '인하다',
 '자다',
 '자세하다',
 '작다',
 '잡다',
 '저렴하다',
 '적다',
 '좋다',
 '좋아하다',
 '주다',
 '중요하다',
 '즐기다',
 '지다',
 '찍다',
 '차다',
 '찾다',
 '크다',
 '특히',
 '편하다',
 '필요하다',
 '해드리다',
 '해보다',
 '해주다',
 '힘들다',
'Credibility']

# %%
feature_1 = ['effort_text','effort_img','experience','Img_count','Media_count','Map_exist','Left','Center','Right','Justify', 'basic_font_check','basic_font_size_check','b_strong_word_len_ratio','color_rgb_word_len_ratio','FR_url','Sticker_count','Blog_info_text_len','Opening_date','Title_len','Text_similarity','pos_ratio','neg_ratio','polarity','subjectivity','Comment_count','Heart_count','Post_interval_average','Total_post']

# %%
import os
import sqlite3
import pandas as pd
import tqdm
import numpy as np
db_name = '[TFIDF]Credibility_research_20180906.db' #DB 파일명
# db 생성
con = sqlite3.connect( db_name )
cur = con.cursor()

# %%
sql = '''
select p.Post_id,p.Category,u.Blog_nickname, u.User_id, p.Title, p.Structure,p.Structure_tag, p.Text, p.Map_exist, p.Heart_count, p.Comment_count, u.Blog_name, u.Blog_nickname, u.Blog_info_text,u.Count_neighbors,u.Count_visitors,u.Categories,u.Count_categories,u.Total_post,u.Blog_mobile_profile_img,u.Blog_mobile_cover_img,u.Opening_date,u.Post_interval_average,ps.Align, ps.basic_font,ps.basic_font_size,ps.b_strong_word_len,ps.color_rgb_word_len,ps.b_tag_len,ps.color_tag_len, group_concat(img.Img_id) as img_count, u.Credibility
    FROM Post as p
    Left JOIN user as u
        ON p.User_id = u.User_id
    Left JOIN Post_style as ps
        ON p.Post_id = ps.Post_id
    Left JOIN Img as img
        ON p.Post_id = img.Post_id
    GROUP BY p.Post_id;
'''
cur.execute(sql)
rows = cur.fetchall()

# %%
col_name = [i[0] for i in cur.description]

# %%
test_df = pd.DataFrame(rows)

# %%
test_df.columns = col_name

# %%
'Blog_mobile_profile_img'
'Blog_mobile_cover_img'

# %%
test_df.columns.tolist()
# Out:
# ['Post_id',
#  'Category',
#  'Blog_nickname',
#  'User_Id',
#  'Title',
#  'Structure',
#  'Structure_tag',
#  'Text',
#  'Map_exist',
#  'Heart_count',
#  'Comment_count',
#  'Blog_name',
#  'Blog_nickname',
#  'Blog_info_text',
#  'Count_neighbors',
#  'Count_visitors',
#  'Categories',
#  'Count_categories',
#  'Total_post',
#  'Blog_mobile_profile_img',
#  'Blog_mobile_cover_img',
#  'Opening_date',
#  'Post_interval_average',
#  'Align',
#  'basic_font',
#  'basic_font_size',
#  'b_strong_word_len',
#  'color_rgb_word_len',
#  'b_tag_len',
#  'color_tag_len',
#  'img_count',
#  'Credibility']

# %%
import pandas as pd

# %%
df = pd.read_csv('[Final]Total_computational_df.csv',encoding='utf-8',sep='\t')

# %%
df.columns.tolist()
# Out:
# ['Post_id',
#  'Title_len',
#  'Count_space_mistake',
#  'Map_exist',
#  'Media_count',
#  'Heart_count',
#  'Sticker_count',
#  'Comment_count',
#  'Left',
#  'Center',
#  'Right',
#  'Justify',
#  'basic_font_check',
#  'basic_font_size_check',
#  'b_strong_word_len_ratio',
#  'color_rgb_word_len_ratio',
#  'First_ratio',
#  'Second_ratio',
#  'Text_len',
#  'Img_count',
#  'FR_url',
#  'pos_ratio',
#  'neg_ratio',
#  'subjectivity',
#  'polarity',
#  'senti_diffs_per_ref',
#  '가능하다',
#  '가다',
#  '간단하다',
#  '갈다',
#  '계시다',
#  '궁금하다',
#  '그렇다',
#  '깔끔하다',
#  '나가다',
#  '나다',
#  '나오다',
#  '남다',
#  '내다',
#  '너무',
#  '넘다',
#  '넣다',
#  '높다',
#  '느끼다',
#  '늘다',
#  '다니다',
#  '다르다',
#  '다양하다',
#  '덥다',
#  '돼다',
#  '되다',
#  '되어다',
#  '두다',
#  '드리다',
#  '들다',
#  '들어가다',
#  '들이다',
#  '따르다',
#  '만나다',
#  '만들다',
#  '많다',
#  '많이',
#  '말다',
#  '맛있다',
#  '맞다',
#  '먹다',
#  '모르다',
#  '믿다',
#  '바라다',
#  '받다',
#  '버리다',
#  '보내다',
#  '보다',
#  '보이다',
#  '빠르다',
#  '빠지다',
#  '새롭다',
#  '생기다',
#  '서다',
# ...

# %%
subjectivity = df['subjectivity'].tolist()
Blog_mobile_profile_img = df['Blog_mobile_profile_img'].tolist()
Blog_mobile_cover_img = df['Blog_mobile_cover_img'].tolist()
Post_id = df['Post_id'].tolist()

# %%
Human_df = pd.read_csv('[Final]Human_df.csv',sep='\t',encoding='utf-8')

# %%
Human_df['subjectivity'] = subjectivity
Human_df['Blog_mobile_profile_img'] = Blog_mobile_profile_img
Human_df['Blog_mobile_cover_img'] = Blog_mobile_cover_img
Human_df['Post_id'] = Post_id

# %%
len(Human_df.columns.tolist())
# Out:
# 245

# %%
New_df = Human_df[col_name]

# %%
New_df.to_csv('[Final]Human_df.csv',sep='\t',encoding='utf-8',index=False)

# %%
col_name = ['Post_id',
    'effort_text',
 'effort_img',
 'experience',
 'Img_count',
 'Media_count',
 'Map_exist',
 'Left',
 'Center',
 'Right',
 'Justify',
 'basic_font_check',
 'basic_font_size_check',
 'b_strong_word_len_ratio',
 'color_rgb_word_len_ratio',
 'FR_url',
 'Sticker_count',
 'Blog_info_text_len',
 'Opening_date',
 'Title_len',
 'Text_similarity',
 'pos_ratio',
 'neg_ratio',
 'polarity',
 'subjectivity',
 'Comment_count',
 'Heart_count',
 'Post_interval_average',
 'Total_post',
'Blog_mobile_profile_img',
 'Blog_mobile_cover_img',
'img img img img img',
 'img img img img text',
 'img img img text img',
 'img img text img img',
 'img img text img text',
 'img text img img img',
 'img text img img text',
 'img text img text img',
 'text img img img img',
 'text img img img text',
 'text img img text img',
 'text img text img img',
 'text img text img text',
 '24시스터디카페',
 'it',
 'lg액정수리',
 '강남서울밝은안과',
 '결혼',
 '결혼준비',
 '골프',
 '공연',
 '교육',
 '국내여행',
 '귀성형수술',
 '김앤방여성의원',
 '누운귀성형',
 '눈썹문신',
 '다이어트',
 '대전맛집',
 '더새로이',
 '데일리룩',
 '돌출귀성형',
 '드라마',
 '디자인',
 '로맨틱그랑서울',
 '리뷰',
 '만화',
 '맛집',
 '몬스터폰',
 '미용',
 '뱃살성형',
 '뱃살수술',
 '복부성형',
 '복부성형가격',
 '복부성형후기',
 '복부수술',
 '본스타트레이닝센터',
 '부산',
 '부산치과',
 '비에이블스터디카페',
 '사진',
 '생각',
 '세계여행',
 '스터디장소',
 '스터디카페',
 '스터디카페추천',
 '스포츠',
 '스포츠분석',
 '스포츠중계',
 '시험준비',
 '신차드림',
 '아나레슨',
 '아나운서학원',
 '아이폰배터리할인',
 '아이폰수리',
 '아이폰액정수리',
 '애니',
 '애니메이션',
 '어린이영양제',
 '에이치비성형외과',
 '여행',
 '연기학원',
 '영어공부',
 '영어회화',
 '영화',
 '웨딩박람회',
 '육아',
 '이벤트',
 '일본여행',
 '일상',
 '임플란트',
 '입꼬리성형',
 '입꼬리성형수술',
 '입꼬리수술',
 '입꼬리수술비용',
 '입꼬리수술잘하는곳',
 '자격증',
 '자동차',
 '자동차리스',
 '장기렌트',
 '장기렌트카',
 '재택알바',
 '제주도',
 '제주도여행',
 '제주여행',
 '주식',
 '주식투자',
 '줄기세포가슴지방이식',
 '중간고사',
 '중고폰매입',
 '직장인미팅',
 '직장인솔로대첩',
 '창업',
 '처진뱃살',
 '첫글',
 '청담여신성형외과',
 '취미',
 '키성장영양제',
 '키영양제',
 '키크는방법',
 '키크는법',
 '패션',
 '학문',
 '가능하다',
 '가다',
 '간단하다',
 '갈다',
 '계시다',
 '궁금하다',
 '그렇다',
 '깔끔하다',
 '나가다',
 '나다',
 '나오다',
 '남다',
 '내다',
 '너무',
 '넘다',
 '넣다',
 '높다',
 '느끼다',
 '늘다',
 '다니다',
 '다르다',
 '다양하다',
 '덥다',
 '돼다',
 '되다',
 '되어다',
 '두다',
 '드리다',
 '들다',
 '들어가다',
 '들이다',
 '따르다',
 '만나다',
 '만들다',
 '많다',
 '많이',
 '말다',
 '맛있다',
 '맞다',
 '먹다',
 '모르다',
 '믿다',
 '바라다',
 '받다',
 '버리다',
 '보내다',
 '보다',
 '보이다',
 '빠르다',
 '빠지다',
 '새롭다',
 '생기다',
 '서다',
 '쉬다',
 '시원하다',
 '싶다',
 '쓰다',
 '아니다',
 '아직',
 '안녕하다',
 '안되다',
 '않다',
 '알다',
 '알아보다',
 '어떻다',
 '어렵다',
 '없다',
 '없이',
 '예쁘다',
 '오다',
 '올리다',
 '원하다',
 '유명하다',
 '이렇게',
 '이렇다',
 '이르다',
 '인하다',
 '자다',
 '자세하다',
 '작다',
 '잡다',
 '저렴하다',
 '적다',
 '좋다',
 '좋아하다',
 '주다',
 '중요하다',
 '즐기다',
 '지다',
 '찍다',
 '차다',
 '찾다',
 '크다',
 '특히',
 '편하다',
 '필요하다',
 '해드리다',
 '해보다',
 '해주다',
 '힘들다', 
'Credibility',]
